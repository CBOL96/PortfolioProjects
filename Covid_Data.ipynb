# %%
import pandas as pd
df_deaths = pd.read_csv(r'C:\Users\carli\Documents\Data Analysis\Projects\SQL Data Exploration\CovidDeaths.csv')
df_vaccination = pd.read_csv(r'C:\Users\carli\Documents\Data Analysis\Projects\SQL Data Exploration\CovidVaccinations.csv')

# %%
df_deaths.head()
# Out:
#   iso_code continent     location       date  population  total_cases  \
# 0      AFG      Asia  Afghanistan  2/24/2020  38928341.0          1.0
# 1      AFG      Asia  Afghanistan  2/25/2020  38928341.0          1.0
# 2      AFG      Asia  Afghanistan  2/26/2020  38928341.0          1.0
# 3      AFG      Asia  Afghanistan  2/27/2020  38928341.0          1.0
# 4      AFG      Asia  Afghanistan  2/28/2020  38928341.0          1.0
#
#    new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# 0        1.0                 NaN           NaN         NaN  ...
# 1        0.0                 NaN           NaN         NaN  ...
# 2        0.0                 NaN           NaN         NaN  ...
# 3        0.0                 NaN           NaN         NaN  ...
# 4        0.0                 NaN           NaN         NaN  ...
#
#    new_deaths_smoothed_per_million  reproduction_rate  icu_patients  \
# 0                              NaN                NaN           NaN
# ...

# %%
df_vaccination.head()
# Out:
#   iso_code continent     location       date  new_tests  total_tests  \
# 0      AFG      Asia  Afghanistan  2/24/2020        NaN          NaN
# 1      AFG      Asia  Afghanistan  2/25/2020        NaN          NaN
# 2      AFG      Asia  Afghanistan  2/26/2020        NaN          NaN
# 3      AFG      Asia  Afghanistan  2/27/2020        NaN          NaN
# 4      AFG      Asia  Afghanistan  2/28/2020        NaN          NaN
#
#    total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 0                       NaN                     NaN                 NaN
# 1                       NaN                     NaN                 NaN
# 2                       NaN                     NaN                 NaN
# 3                       NaN                     NaN                 NaN
# 4                       NaN                     NaN                 NaN
#
#    new_tests_smoothed_per_thousand  ...  gdp_per_capita  extreme_poverty  \
# ...

# %%
from sqlalchemy import create_engine

# Configura los datos de conexión
USER = "root"
PASSWORD = "Messier31"
HOST = "localhost"  
PORT = "3306"  # Puerto de MySQL
DATABASE = "portfolioprojects"

# Crear la conexión con SQLAlchemy
engine = create_engine(f"mysql+mysqlconnector://{USER}:{PASSWORD}@{HOST}:{PORT}/{DATABASE}")

# %%
#Load data into sql server using append option
df_deaths.to_sql('covid_deaths',con=engine.connect(),index=False,if_exists = 'append')
df_vaccination.to_sql('covid_vaccination',con=engine.connect(),index=False,if_exists = 'append')
# Out:
# 85171

# %%
engine.connect().close()
